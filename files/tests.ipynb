# %%
import pandas as pd
# para leer file .csv con pandas.
file = pd.read_csv("./file.csv")

file
# Out:
#       name lastname  age
# 0   andres  ramirez   26
# 1  roberto     melo   18
# 2     pepe    perez   20
